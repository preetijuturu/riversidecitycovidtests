# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as pat

# %%
riverside = gpd.read_file('https://opendata.arcgis.com/datasets/6d2ef294a5114c8eaa0be9344a63f1d9_0.geojson')
print(riverside.head())
# Out:
#    FID         AREA      PERIMETER  WARD_NUMB          PERSON TERMEXPIRE  \
# 0    1  7557.215889  130429.912390          1    ERIN EDWARDS      03/24
# 1    2  9265.574997  143554.533063          2  ANDY MELENDREZ      06/21
# 2    3  8033.286802  113411.769163          3  RONALDO FIERRO      03/24
# 3    4  6794.134333   95624.089566          7  STEVE HEMENWAY      03/24
# 4    5  4040.096589   89874.281286          6       JIM PERRY      06/21
#
#                                         URLLink  SHAPE_Length  SHAPE_Area  \
# 0  https://riversideca.gov/council/wards/ward-1      0.403778    0.002984
# 1  https://riversideca.gov/council/wards/ward-2      0.438993    0.003657
# 2  https://riversideca.gov/council/wards/ward-3      0.352152    0.003170
# 3  https://riversideca.gov/council/wards/ward-7      0.289932    0.002681
# 4  https://riversideca.gov/council/wards/ward-6      0.275727    0.001594
#
#                                             geometry
# ...

# %%
riverside.plot(figsize=(8, 8))
# Out:
# <AxesSubplot:>
